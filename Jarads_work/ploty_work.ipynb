# %%
import pandas as pd
import numpy as np
import plotly.graph_objs as go

# %%
df = pd.read_csv('global_bands.csv')

# %%
df.head()
# Out:
#                             year   production      midband           ub  \
# 0  1960-01-01 00:00:00.000000000  3907.136963  3907.136963          NaN
# 1  1961-01-01 00:00:00.000000000  4119.667969  4066.535217  4517.381564
# 2  1962-01-01 00:00:00.000000000  4229.048828  4179.044640  4579.695963
# 3  1963-01-01 00:00:00.000000000  4336.933105  4285.619354  4673.372799
# 4  1964-01-01 00:00:00.000000000  4443.379395  4391.227315  4777.010849
#
#             lb
# 0          NaN
# 1  3615.688871
# 2  3778.393317
# 3  3897.865910
# 4  4005.443781

# %%
fig = go.Figure([
    go.Scatter(
        name='Measurement',
        x=df['year'],
        y=df['production'],
        mode='lines',
        line=dict(color='rgb(31, 119, 180)'),
    ),
    go.Scatter(
        name='Upper Bound',
        x=df['year'],
        y=df['ub'],
        mode='lines',
        marker=dict(color="#444"),
        line=dict(width=0),
        showlegend=False
    ),
    go.Scatter(
        name='Lower Bound',
        x=df['year'],
        y=df['lb'],
        marker=dict(color="#444"),
        line=dict(width=0),
        mode='lines',
        fillcolor='rgba(68, 68, 68, 0.3)',
        fill='tonexty',
        showlegend=False
    )
])
fig.update_layout(
    yaxis_title='Global Production Prediction',
    title='Global Production Prediction',
    hovermode="x"
)
fig.show()

# %%
df = pd.read_csv('prod_bol_bands.csv')

# %%
df.head()
# Out:
#          year  production  midband      ub      lb
# 0  1991-01-01      2636.0   2636.0     NaN     NaN
# 1  1992-01-01      2660.0   2654.0  2704.0  2603.0
# 2  1993-01-01      2742.0   2715.0  2896.0  2533.0
# 3  1994-01-01      2762.0   2746.0  2885.0  2608.0
# 4  1995-01-01      2783.0   2771.0  2878.0  2663.0

# %%
fig = go.Figure([
    go.Scatter(
        name='Production',
        x=df['year'],
        y=df['production'],
        mode='lines',
        line=dict(color='rgb(31, 119, 180)'),
    ),
    go.Scatter(
        name='Upper Bound',
        x=df['year'],
        y=df['ub'],
        mode='lines',
        marker=dict(color="#444"),
        line=dict(width=0),
        showlegend=False
    ),
    go.Scatter(
        name='Lower Bound',
        x=df['year'],
        y=df['lb'],
        marker=dict(color="#444"),
        line=dict(width=0),
        mode='lines',
        fillcolor='rgba(68, 68, 68, 0.3)',
        fill='tonexty',
        showlegend=False
    )
])
fig.update_layout(
    yaxis_title='US Production Prediction',
    title='US Production Prediction',
    hovermode="x"
)
fig.show()

# %%
df=pd.read_csv('us_sales_bands.csv')

# %%
fig = go.Figure([
    go.Scatter(
        name='Measurement',
        x=df['year'],
        y=df['sales'],
        mode='lines',
        line=dict(color='rgb(31, 119, 180)'),
    ),
    go.Scatter(
        name='Upper Bound',
        x=df['year'],
        y=df['ub'],
        mode='lines',
        marker=dict(color="#444"),
        line=dict(width=0),
        showlegend=False
    ),
    go.Scatter(
        name='Lower Bound',
        x=df['year'],
        y=df['lb'],
        marker=dict(color="#444"),
        line=dict(width=0),
        mode='lines',
        fillcolor='rgba(68, 68, 68, 0.3)',
        fill='tonexty',
        showlegend=False
    )
])
fig.update_layout(
    yaxis_title='Sales Prediction',
    title='Total New Vehicle Sales Prediction',
    hovermode="x"
)
fig.show()

# %%
import plotly.graph_objects as go


fig = go.Figure(data=[
    go.Bar(name='Pred Sales', x=df.year, y= df.sales),
    go.Line(name='Upper Bound', x=df.year, y=df.ub, line_color='red'),
    go.Line(name='Lower Bound', x=df.year, y=df.lb, line_color='red')

])
# Change the bar mode
fig.update_layout(barmode='group')
fig.show()
# Out:
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/plotly/graph_objs/_deprecations.py:378: DeprecationWarning:
#
# plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.
